# %%
from pyabsa import AspectTermExtraction as ATEPC
# Out:
# /bin/sh: nvidia-smi: command not found
# No CUDA GPU found in your device
# [2024-06-04 20:57:09] (2.3.1) PyABSA(2.3.1): If your code crashes on Colab, please use the GPU runtime. Then run "pip install pyabsa[dev] -U" and restart the kernel.
# Or if it does not work, you can use v1.x versions, e.g., pip install pyabsa<2.0 -U
#
#
#
#
# WARNING: When you fails to load a checkpoint, e.g., Unexpected key(s),
# Try to downgrade transformers<=4.29.0.
# /Users/dehan/opt/anaconda3/lib/python3.9/multiprocessing/pool.py:265: ResourceWarning: unclosed running multiprocessing pool <multiprocessing.pool.Pool state=RUN pool_size=1>
#   _warn(f"unclosed running multiprocessing pool {self!r}",
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
config = (
    ATEPC.ATEPCConfigManager.get_atepc_config_english()
)  # this config contains 'pretrained_bert', it is based on pretrained models
config.model = ATEPC.ATEPCModelList.FAST_LCF_ATEPC  # improved version of LCF-ATEPC

# %%
from pyabsa import DatasetItem
my_dataset = DatasetItem("my_dataset", ["132.manuallabel"])
# my_dataset1 and my_dataset2 are the dataset folders. In there folders, the train dataset is necessary

# %%
from pyabsa import ModelSaveOption, DeviceTypeOption
import warnings

warnings.filterwarnings("ignore")

config.num_epoch = 1
config.batch_size = 16
config.patience = 2
config.log_step = -1
config.seed = [1]
config.verbose = False  # If verbose == True, PyABSA will output the model strcture and seversal processed data examples
config.scenario_case='manuallabelcheckpointoriginal'

trainer = ATEPC.ATEPCTrainer(
    config=config,
    dataset=my_dataset,
    from_checkpoint="/Users/dehan/Documents/SKRIPSIII/PyABSA/checkpoints/ENGLISH_ATE_TOURISM",  # if you want to resume training from our pretrained checkpoints, you can pass the checkpoint name here
    auto_device=DeviceTypeOption.AUTO,  # use cuda if available
    checkpoint_save_mode=ModelSaveOption.SAVE_MODEL_STATE_DICT,  # save state dict only instead of the whole model
    load_aug=False,  # there are some augmentation dataset for integrated datasets, you use them by setting load_aug=True to improve performance
)
# Out:
# [2024-06-04 20:57:44] (2.3.1) Set Model Device: cpu
# [2024-06-04 20:57:44] (2.3.1) Device Name: Unknown
# 2024-06-04 20:57:46,693 INFO: PyABSA version: 2.3.1
# 2024-06-04 20:57:46,694 INFO: Transformers version: 4.29.0
# 2024-06-04 20:57:46,694 INFO: Torch version: 2.1.0.dev20230313+cudaNone
# 2024-06-04 20:57:46,694 INFO: Device: Unknown
# 2024-06-04 20:57:46,695 INFO: Scenario Case: manuallabelcheckpointoriginal
# 2024-06-04 20:57:46,696 INFO: my_dataset in the trainer is not a exact path, will search dataset in current working directory
# 2024-06-04 20:57:46,736 INFO: You can set load_aug=True in a trainer to augment your dataset (English only yet) and improve performance.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# convert examples to features: 100%|██████████| 1072/1072 [00:02<00:00, 447.39it/s]
# 2024-06-04 20:57:53,407 INFO: Dataset Label Details: {'Neutral': 10, 'Negative': 310, 'Positive': 752, 'Sum': 1072}
# convert examples to features: 100%|██████████| 358/358 [00:00<00:00, 466.32it/s]
# 2024-06-04 20:57:54,493 INFO: Dataset Label Details: {'Neutral': 4, 'Negative': 106, 'Positive': 248, 'Sum': 358}
# Some weights of the model checkpoint at microsoft/deberta-v3-base were not used when initializing DebertaV2Model: ['mask_predictions.dense.weight', 'mask_predictions.classifier.bias', 'mask_predictions.LayerNorm.weight', 'lm_predictions.lm_head.dense.weight', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'mask_predictions.classifier.weight', 'mask_predictions.LayerNorm.bias', 'mask_predictions.dense.bias']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2024-06-04 20:57:57,024 INFO: Save cache dataset to fast_lcf_atepc.my_dataset.dataset.ce6abc1c7b585630880e06cd6593b03c91bf4aa52df6599c084f1e483631c859.cache
# 2024-06-04 20:57:57,054 INFO: ABSADatasetsVersion:None	-->	Calling Count:0
# 2024-06-04 20:57:57,054 INFO: IOB_label_to_index:{'B-ASP': 1, 'I-ASP': 2, 'O': 3, '[CLS]': 4, '[SEP]': 5}	-->	Calling Count:1
# 2024-06-04 20:57:57,054 INFO: MV:<metric_visualizer.metric_visualizer.MetricVisualizer object at 0x17ef3c820>	-->	Calling Count:0
# 2024-06-04 20:57:57,055 INFO: PyABSAVersion:2.3.1	-->	Calling Count:1
# 2024-06-04 20:57:57,055 INFO: SRD:3	-->	Calling Count:2860
# 2024-06-04 20:57:57,055 INFO: TorchVersion:2.1.0.dev20230313+cudaNone	-->	Calling Count:1
# 2024-06-04 20:57:57,056 INFO: TransformersVersion:4.29.0	-->	Calling Count:1
# 2024-06-04 20:57:57,056 INFO: auto_device:True	-->	Calling Count:3
# 2024-06-04 20:57:57,057 INFO: batch_size:16	-->	Calling Count:4
# 2024-06-04 20:57:57,057 INFO: cache_dataset:True	-->	Calling Count:1
# 2024-06-04 20:57:57,058 INFO: checkpoint_save_mode:1	-->	Calling Count:4
# 2024-06-04 20:57:57,058 INFO: cross_validate_fold:-1	-->	Calling Count:0
# 2024-06-04 20:57:57,058 INFO: dataset_file:{'train': ['integrated_datasets/atepc_datasets/132.manuallabel/train_set.txt.atepc'], 'test': ['integrated_datasets/atepc_datasets/132.manuallabel/test_set.txt.atepc'], 'valid': []}	-->	Calling Count:6
# 2024-06-04 20:57:57,059 INFO: dataset_name:my_dataset	-->	Calling Count:3
# 2024-06-04 20:57:57,059 INFO: device:cpu	-->	Calling Count:3
# 2024-06-04 20:57:57,060 INFO: device_name:Unknown	-->	Calling Count:1
# 2024-06-04 20:57:57,060 INFO: dropout:0.5	-->	Calling Count:1
# 2024-06-04 20:57:57,060 INFO: dynamic_truncate:True	-->	Calling Count:2860
# 2024-06-04 20:57:57,061 INFO: embed_dim:768	-->	Calling Count:0
# 2024-06-04 20:57:57,061 INFO: evaluate_begin:0	-->	Calling Count:0
# 2024-06-04 20:57:57,061 INFO: from_checkpoint:/Users/dehan/Documents/SKRIPSIII/PyABSA/checkpoints/ENGLISH_ATE_TOURISM	-->	Calling Count:0
# 2024-06-04 20:57:57,062 INFO: gradient_accumulation_steps:1	-->	Calling Count:3
# 2024-06-04 20:57:57,062 INFO: hidden_dim:768	-->	Calling Count:6
# 2024-06-04 20:57:57,062 INFO: index_to_IOB_label:{1: 'B-ASP', 2: 'I-ASP', 3: 'O', 4: '[CLS]', 5: '[SEP]'}	-->	Calling Count:0
# 2024-06-04 20:57:57,063 INFO: index_to_label:{0: 'Negative', 1: 'Neutral', 2: 'Positive'}	-->	Calling Count:2
# 2024-06-04 20:57:57,063 INFO: inference_model:None	-->	Calling Count:0
# 2024-06-04 20:57:57,063 INFO: initializer:xavier_uniform_	-->	Calling Count:0
# 2024-06-04 20:57:57,064 INFO: l2reg:1e-05	-->	Calling Count:2
# 2024-06-04 20:57:57,064 INFO: label_list:['B-ASP', 'I-ASP', 'O', '[CLS]', '[SEP]']	-->	Calling Count:1
# 2024-06-04 20:57:57,065 INFO: label_to_index:{'Negative': 0, 'Neutral': 1, 'Positive': 2}	-->	Calling Count:0
# 2024-06-04 20:57:57,065 INFO: lcf:cdm	-->	Calling Count:0
# 2024-06-04 20:57:57,065 INFO: learning_rate:2e-05	-->	Calling Count:1
# 2024-06-04 20:57:57,066 INFO: load_aug:False	-->	Calling Count:1
# 2024-06-04 20:57:57,066 INFO: log_step:-1	-->	Calling Count:0
# 2024-06-04 20:57:57,066 INFO: logger:<Logger fast_lcf_atepc (INFO)>	-->	Calling Count:10
# 2024-06-04 20:57:57,067 INFO: max_seq_len:80	-->	Calling Count:10012
# 2024-06-04 20:57:57,067 INFO: model:<class 'pyabsa.tasks.AspectTermExtraction.models.__lcf__.fast_lcf_atepc.FAST_LCF_ATEPC'>	-->	Calling Count:5
# 2024-06-04 20:57:57,067 INFO: model_name:fast_lcf_atepc	-->	Calling Count:1432
# 2024-06-04 20:57:57,068 INFO: model_path_to_save:checkpoints	-->	Calling Count:2
# 2024-06-04 20:57:57,068 INFO: num_epoch:1	-->	Calling Count:1
# 2024-06-04 20:57:57,068 INFO: num_labels:6	-->	Calling Count:2
# 2024-06-04 20:57:57,069 INFO: optimizer:adamw	-->	Calling Count:2
# 2024-06-04 20:57:57,069 INFO: output_dim:3	-->	Calling Count:1
# 2024-06-04 20:57:57,069 INFO: overwrite_cache:False	-->	Calling Count:0
# 2024-06-04 20:57:57,070 INFO: path_to_save:None	-->	Calling Count:1
# 2024-06-04 20:57:57,070 INFO: patience:2	-->	Calling Count:0
# 2024-06-04 20:57:57,071 INFO: pretrained_bert:microsoft/deberta-v3-base	-->	Calling Count:5
# 2024-06-04 20:57:57,071 INFO: save_mode:1	-->	Calling Count:0
# 2024-06-04 20:57:57,071 INFO: scenario_case:manuallabelcheckpointoriginal	-->	Calling Count:1
# 2024-06-04 20:57:57,072 INFO: seed:1	-->	Calling Count:6
# 2024-06-04 20:57:57,073 INFO: sep_indices:2	-->	Calling Count:0
# 2024-06-04 20:57:57,075 INFO: show_metric:False	-->	Calling Count:0
# 2024-06-04 20:57:57,076 INFO: spacy_model:en_core_web_sm	-->	Calling Count:3
# 2024-06-04 20:57:57,077 INFO: srd_alignment:True	-->	Calling Count:0
# 2024-06-04 20:57:57,078 INFO: task_code:ATEPC	-->	Calling Count:1
# 2024-06-04 20:57:57,081 INFO: task_name:Aspect Term Extraction and Polarity Classification	-->	Calling Count:0
# 2024-06-04 20:57:57,082 INFO: use_amp:False	-->	Calling Count:1
# 2024-06-04 20:57:57,083 INFO: use_bert_spc:True	-->	Calling Count:0
# 2024-06-04 20:57:57,086 INFO: use_syntax_based_SRD:False	-->	Calling Count:1430
# 2024-06-04 20:57:57,090 INFO: verbose:False	-->	Calling Count:0
# 2024-06-04 20:57:57,092 INFO: warmup_step:-1	-->	Calling Count:0
# 2024-06-04 20:57:57,092 INFO: window:lr	-->	Calling Count:0
# 2024-06-04 20:57:57,095 INFO: ABSADatasetsVersion:None	-->	Calling Count:0
# 2024-06-04 20:57:57,098 INFO: IOB_label_to_index:{'B-ASP': 1, 'I-ASP': 2, 'O': 3, '[CLS]': 4, '[SEP]': 5}	-->	Calling Count:1
# 2024-06-04 20:57:57,100 INFO: MV:<metric_visualizer.metric_visualizer.MetricVisualizer object at 0x17ef3c820>	-->	Calling Count:0
# 2024-06-04 20:57:57,101 INFO: PyABSAVersion:2.3.1	-->	Calling Count:1
# 2024-06-04 20:57:57,102 INFO: SRD:3	-->	Calling Count:2860
# 2024-06-04 20:57:57,105 INFO: TorchVersion:2.1.0.dev20230313+cudaNone	-->	Calling Count:1
# 2024-06-04 20:57:57,107 INFO: TransformersVersion:4.29.0	-->	Calling Count:1
# 2024-06-04 20:57:57,109 INFO: auto_device:True	-->	Calling Count:4
# 2024-06-04 20:57:57,110 INFO: batch_size:16	-->	Calling Count:4
# 2024-06-04 20:57:57,112 INFO: cache_dataset:True	-->	Calling Count:1
# 2024-06-04 20:57:57,114 INFO: checkpoint_save_mode:1	-->	Calling Count:4
# 2024-06-04 20:57:57,115 INFO: cross_validate_fold:-1	-->	Calling Count:1
# 2024-06-04 20:57:57,115 INFO: dataset_file:{'train': ['integrated_datasets/atepc_datasets/132.manuallabel/train_set.txt.atepc'], 'test': ['integrated_datasets/atepc_datasets/132.manuallabel/test_set.txt.atepc'], 'valid': []}	-->	Calling Count:6
# 2024-06-04 20:57:57,116 INFO: dataset_name:my_dataset	-->	Calling Count:3
# 2024-06-04 20:57:57,116 INFO: device:cpu	-->	Calling Count:6
# 2024-06-04 20:57:57,116 INFO: device_name:Unknown	-->	Calling Count:1
# 2024-06-04 20:57:57,116 INFO: dropout:0.5	-->	Calling Count:1
# 2024-06-04 20:57:57,117 INFO: dynamic_truncate:True	-->	Calling Count:2860
# 2024-06-04 20:57:57,117 INFO: embed_dim:768	-->	Calling Count:0
# 2024-06-04 20:57:57,117 INFO: evaluate_begin:0	-->	Calling Count:0
# 2024-06-04 20:57:57,118 INFO: from_checkpoint:/Users/dehan/Documents/SKRIPSIII/PyABSA/checkpoints/ENGLISH_ATE_TOURISM	-->	Calling Count:0
# 2024-06-04 20:57:57,118 INFO: gradient_accumulation_steps:1	-->	Calling Count:3
# 2024-06-04 20:57:57,118 INFO: hidden_dim:768	-->	Calling Count:6
# 2024-06-04 20:57:57,119 INFO: index_to_IOB_label:{1: 'B-ASP', 2: 'I-ASP', 3: 'O', 4: '[CLS]', 5: '[SEP]'}	-->	Calling Count:0
# 2024-06-04 20:57:57,119 INFO: index_to_label:{0: 'Negative', 1: 'Neutral', 2: 'Positive'}	-->	Calling Count:2
# 2024-06-04 20:57:57,119 INFO: inference_model:None	-->	Calling Count:0
# 2024-06-04 20:57:57,120 INFO: initializer:xavier_uniform_	-->	Calling Count:0
# 2024-06-04 20:57:57,121 INFO: l2reg:1e-05	-->	Calling Count:2
# 2024-06-04 20:57:57,122 INFO: label_list:['B-ASP', 'I-ASP', 'O', '[CLS]', '[SEP]']	-->	Calling Count:1
# 2024-06-04 20:57:57,123 INFO: label_to_index:{'Negative': 0, 'Neutral': 1, 'Positive': 2}	-->	Calling Count:0
# 2024-06-04 20:57:57,125 INFO: lcf:cdm	-->	Calling Count:0
# 2024-06-04 20:57:57,126 INFO: learning_rate:2e-05	-->	Calling Count:1
# 2024-06-04 20:57:57,127 INFO: load_aug:False	-->	Calling Count:1
# 2024-06-04 20:57:57,128 INFO: log_step:-1	-->	Calling Count:0
# 2024-06-04 20:57:57,128 INFO: logger:<Logger fast_lcf_atepc (INFO)>	-->	Calling Count:10
# 2024-06-04 20:57:57,129 INFO: max_seq_len:80	-->	Calling Count:10012
# 2024-06-04 20:57:57,129 INFO: model:<class 'pyabsa.tasks.AspectTermExtraction.models.__lcf__.fast_lcf_atepc.FAST_LCF_ATEPC'>	-->	Calling Count:5
# 2024-06-04 20:57:57,129 INFO: model_name:fast_lcf_atepc	-->	Calling Count:1432
# 2024-06-04 20:57:57,129 INFO: model_path_to_save:checkpoints	-->	Calling Count:2
# 2024-06-04 20:57:57,130 INFO: num_epoch:1	-->	Calling Count:1
# 2024-06-04 20:57:57,130 INFO: num_labels:6	-->	Calling Count:2
# 2024-06-04 20:57:57,131 INFO: optimizer:adamw	-->	Calling Count:2
# 2024-06-04 20:57:57,131 INFO: output_dim:3	-->	Calling Count:1
# 2024-06-04 20:57:57,131 INFO: overwrite_cache:False	-->	Calling Count:0
# 2024-06-04 20:57:57,132 INFO: path_to_save:None	-->	Calling Count:1
# 2024-06-04 20:57:57,132 INFO: patience:2	-->	Calling Count:0
# 2024-06-04 20:57:57,132 INFO: pretrained_bert:microsoft/deberta-v3-base	-->	Calling Count:5
# 2024-06-04 20:57:57,133 INFO: save_mode:1	-->	Calling Count:0
# 2024-06-04 20:57:57,133 INFO: scenario_case:manuallabelcheckpointoriginal	-->	Calling Count:1
# 2024-06-04 20:57:57,133 INFO: seed:1	-->	Calling Count:6
# 2024-06-04 20:57:57,134 INFO: sep_indices:2	-->	Calling Count:0
# 2024-06-04 20:57:57,134 INFO: show_metric:False	-->	Calling Count:0
# 2024-06-04 20:57:57,134 INFO: spacy_model:en_core_web_sm	-->	Calling Count:3
# 2024-06-04 20:57:57,135 INFO: srd_alignment:True	-->	Calling Count:0
# 2024-06-04 20:57:57,135 INFO: task_code:ATEPC	-->	Calling Count:1
# 2024-06-04 20:57:57,135 INFO: task_name:Aspect Term Extraction and Polarity Classification	-->	Calling Count:0
# 2024-06-04 20:57:57,136 INFO: tokenizer:DebertaV2TokenizerFast(name_or_path='microsoft/deberta-v3-base', vocab_size=128000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '[CLS]', 'eos_token': '[SEP]', 'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True)	-->	Calling Count:0
# 2024-06-04 20:57:57,136 INFO: use_amp:False	-->	Calling Count:1
# 2024-06-04 20:57:57,137 INFO: use_bert_spc:True	-->	Calling Count:0
# 2024-06-04 20:57:57,137 INFO: use_syntax_based_SRD:False	-->	Calling Count:1430
# 2024-06-04 20:57:57,137 INFO: verbose:False	-->	Calling Count:1
# 2024-06-04 20:57:57,137 INFO: warmup_step:-1	-->	Calling Count:0
# 2024-06-04 20:57:57,138 INFO: window:lr	-->	Calling Count:0
# 2024-06-04 20:57:57,942 INFO: Resume trainer from Checkpoint: /Users/dehan/Documents/SKRIPSIII/PyABSA/checkpoints/ENGLISH_ATE_TOURISM!
# 2024-06-04 20:57:58,018 INFO: ***** Running training for Aspect Term Extraction and Polarity Classification *****
# 2024-06-04 20:57:58,018 INFO:   Num examples = 1072
# 2024-06-04 20:57:58,019 INFO:   Batch size = 16
# 2024-06-04 20:57:58,020 INFO:   Num steps = 67
# Epoch:  0| loss_apc:0.4060 | loss_ate:0.1511 |: 100%|██████████| 67/67 [03:49<00:00,  3.42s/it,  APC_ACC: 77.65(max:77.65) | APC_F1: 45.03(max:45.03) | APC_PRECISION: 44.03(max:44.03) | APC_RECALL: 53.61(max:53.61) |  ATE_F1: 10.86(max:10.86)]
# 2024-06-04 21:02:02,309 INFO:
# ---------------------------------------------------------------------- Raw Metric Records ----------------------------------------------------------------------
# ╒══════════════════════════════════════╤═════════════════════════════════════════════════════╤══════════╤═══════════╤══════════╤═══════╤═══════╤═══════╤═══════╕
# │ Metric                               │ Trial                                               │ Values   │  Average  │  Median  │  Std  │  IQR  │  Min  │  Max  │
# ╞══════════════════════════════════════╪═════════════════════════════════════════════════════╪══════════╪═══════════╪══════════╪═══════╪═══════╪═══════╪═══════╡
# │ Max-APC-Test-Acc w/o Valid Set       │ fast_lcf_atepc-my_dataset-microsoft/deberta-v3-base │ [77.65]  │   77.65   │  77.65   │   0   │   0   │ 77.65 │ 77.65 │
# ├──────────────────────────────────────┼─────────────────────────────────────────────────────┼──────────┼───────────┼──────────┼───────┼───────┼───────┼───────┤
# │ Max-APC-Test-F1 w/o Valid Set        │ fast_lcf_atepc-my_dataset-microsoft/deberta-v3-base │ [45.03]  │   45.03   │  45.03   │   0   │   0   │ 45.03 │ 45.03 │
# ├──────────────────────────────────────┼─────────────────────────────────────────────────────┼──────────┼───────────┼──────────┼───────┼───────┼───────┼───────┤
# │ Max-APC-Test-Precision w/o Valid Set │ fast_lcf_atepc-my_dataset-microsoft/deberta-v3-base │ [44.03]  │   44.03   │  44.03   │   0   │   0   │ 44.03 │ 44.03 │
# ├──────────────────────────────────────┼─────────────────────────────────────────────────────┼──────────┼───────────┼──────────┼───────┼───────┼───────┼───────┤
# │ Max-APC-Test-Recall w/o Valid Set    │ fast_lcf_atepc-my_dataset-microsoft/deberta-v3-base │ [53.61]  │   53.61   │  53.61   │   0   │   0   │ 53.61 │ 53.61 │
# ├──────────────────────────────────────┼─────────────────────────────────────────────────────┼──────────┼───────────┼──────────┼───────┼───────┼───────┼───────┤
# │ Max-ATE-Test-F1 w/o Valid Set        │ fast_lcf_atepc-my_dataset-microsoft/deberta-v3-base │ [10.86]  │   10.86   │  10.86   │   0   │   0   │ 10.86 │ 10.86 │
# ╘══════════════════════════════════════╧═════════════════════════════════════════════════════╧══════════╧═══════════╧══════════╧═══════╧═══════╧═══════╧═══════╛
# ------------------------------------------------------- https://github.com/yangheng95/metric_visualizer -------------------------------------------------------
#
# 2024-06-04 21:02:02,313 INFO: ABSADatasetsVersion:None	-->	Calling Count:0
# 2024-06-04 21:02:02,314 INFO: IOB_label_to_index:{'B-ASP': 1, 'I-ASP': 2, 'O': 3, '[CLS]': 4, '[SEP]': 5}	-->	Calling Count:1
# 2024-06-04 21:02:02,314 INFO: MV:<metric_visualizer.metric_visualizer.MetricVisualizer object at 0x17ef3c820>	-->	Calling Count:6
# 2024-06-04 21:02:02,315 INFO: PyABSAVersion:2.3.1	-->	Calling Count:1
# 2024-06-04 21:02:02,315 INFO: SRD:3	-->	Calling Count:2860
# 2024-06-04 21:02:02,315 INFO: TorchVersion:2.1.0.dev20230313+cudaNone	-->	Calling Count:1
# 2024-06-04 21:02:02,316 INFO: TransformersVersion:4.29.0	-->	Calling Count:1
# 2024-06-04 21:02:02,316 INFO: auto_device:True	-->	Calling Count:71
# 2024-06-04 21:02:02,316 INFO: batch_size:16	-->	Calling Count:6
# 2024-06-04 21:02:02,316 INFO: cache_dataset:True	-->	Calling Count:1
# 2024-06-04 21:02:02,317 INFO: checkpoint_save_mode:1	-->	Calling Count:4
# 2024-06-04 21:02:02,317 INFO: cross_validate_fold:-1	-->	Calling Count:2
# 2024-06-04 21:02:02,317 INFO: dataset_file:{'train': ['integrated_datasets/atepc_datasets/132.manuallabel/train_set.txt.atepc'], 'test': ['integrated_datasets/atepc_datasets/132.manuallabel/test_set.txt.atepc'], 'valid': []}	-->	Calling Count:6
# 2024-06-04 21:02:02,318 INFO: dataset_name:my_dataset	-->	Calling Count:10
# 2024-06-04 21:02:02,318 INFO: device:cpu	-->	Calling Count:1026
# 2024-06-04 21:02:02,318 INFO: device_name:Unknown	-->	Calling Count:1
# 2024-06-04 21:02:02,318 INFO: dropout:0.5	-->	Calling Count:1
# 2024-06-04 21:02:02,319 INFO: dynamic_truncate:True	-->	Calling Count:2860
# 2024-06-04 21:02:02,319 INFO: embed_dim:768	-->	Calling Count:0
# 2024-06-04 21:02:02,319 INFO: evaluate_begin:0	-->	Calling Count:2
# 2024-06-04 21:02:02,320 INFO: from_checkpoint:/Users/dehan/Documents/SKRIPSIII/PyABSA/checkpoints/ENGLISH_ATE_TOURISM	-->	Calling Count:3
# 2024-06-04 21:02:02,320 INFO: gradient_accumulation_steps:1	-->	Calling Count:3
# 2024-06-04 21:02:02,320 INFO: hidden_dim:768	-->	Calling Count:6
# 2024-06-04 21:02:02,320 INFO: index_to_IOB_label:{1: 'B-ASP', 2: 'I-ASP', 3: 'O', 4: '[CLS]', 5: '[SEP]'}	-->	Calling Count:0
# 2024-06-04 21:02:02,321 INFO: index_to_label:{0: 'Negative', 1: 'Neutral', 2: 'Positive'}	-->	Calling Count:2
# 2024-06-04 21:02:02,321 INFO: inference_model:None	-->	Calling Count:0
# 2024-06-04 21:02:02,321 INFO: initializer:xavier_uniform_	-->	Calling Count:0
# 2024-06-04 21:02:02,321 INFO: l2reg:1e-05	-->	Calling Count:2
# 2024-06-04 21:02:02,322 INFO: label_list:['B-ASP', 'I-ASP', 'O', '[CLS]', '[SEP]']	-->	Calling Count:3
# 2024-06-04 21:02:02,322 INFO: label_to_index:{'Negative': 0, 'Neutral': 1, 'Positive': 2}	-->	Calling Count:0
# 2024-06-04 21:02:02,323 INFO: lcf:cdm	-->	Calling Count:114
# 2024-06-04 21:02:02,323 INFO: learning_rate:2e-05	-->	Calling Count:1
# 2024-06-04 21:02:02,323 INFO: load_aug:False	-->	Calling Count:1
# 2024-06-04 21:02:02,324 INFO: log_step:67	-->	Calling Count:69
# 2024-06-04 21:02:02,324 INFO: logger:<Logger fast_lcf_atepc (INFO)>	-->	Calling Count:11
# 2024-06-04 21:02:02,324 INFO: loss:0.8550237536430358	-->	Calling Count:0
# 2024-06-04 21:02:02,325 INFO: max_seq_len:80	-->	Calling Count:10238
# 2024-06-04 21:02:02,325 INFO: max_test_metrics:{'max_apc_test_acc': 77.65, 'max_apc_test_f1': 45.03, 'max_apc_test_precision': 44.03, 'max_apc_test_recall': 53.61, 'max_ate_test_f1': 10.86}	-->	Calling Count:21
# 2024-06-04 21:02:02,325 INFO: metrics_of_this_checkpoint:{'apc_acc': 77.65, 'apc_f1': 45.03, 'apc_precision': 44.03, 'apc_recall': 53.61, 'ate_f1': 10.86}	-->	Calling Count:5
# 2024-06-04 21:02:02,325 INFO: model:<class 'pyabsa.tasks.AspectTermExtraction.models.__lcf__.fast_lcf_atepc.FAST_LCF_ATEPC'>	-->	Calling Count:5
# 2024-06-04 21:02:02,326 INFO: model_name:fast_lcf_atepc	-->	Calling Count:1443
# 2024-06-04 21:02:02,326 INFO: model_path_to_save:checkpoints	-->	Calling Count:5
# 2024-06-04 21:02:02,326 INFO: num_epoch:1	-->	Calling Count:2
# 2024-06-04 21:02:02,326 INFO: num_labels:6	-->	Calling Count:2
# 2024-06-04 21:02:02,327 INFO: optimizer:adamw	-->	Calling Count:2
# 2024-06-04 21:02:02,327 INFO: output_dim:3	-->	Calling Count:7
# 2024-06-04 21:02:02,327 INFO: overwrite_cache:False	-->	Calling Count:0
# 2024-06-04 21:02:02,327 INFO: path_to_save:None	-->	Calling Count:1
# 2024-06-04 21:02:02,327 INFO: patience:2	-->	Calling Count:2
# 2024-06-04 21:02:02,328 INFO: pretrained_bert:microsoft/deberta-v3-base	-->	Calling Count:10
# 2024-06-04 21:02:02,328 INFO: save_mode:1	-->	Calling Count:2
# 2024-06-04 21:02:02,328 INFO: scenario_case:manuallabelcheckpointoriginal	-->	Calling Count:1
# 2024-06-04 21:02:02,328 INFO: seed:1	-->	Calling Count:6
# 2024-06-04 21:02:02,329 INFO: sep_indices:2	-->	Calling Count:2504
# 2024-06-04 21:02:02,329 INFO: show_metric:False	-->	Calling Count:0
# 2024-06-04 21:02:02,329 INFO: spacy_model:en_core_web_sm	-->	Calling Count:3
# 2024-06-04 21:02:02,330 INFO: srd_alignment:True	-->	Calling Count:0
# 2024-06-04 21:02:02,330 INFO: task_code:ATEPC	-->	Calling Count:1
# 2024-06-04 21:02:02,330 INFO: task_name:Aspect Term Extraction and Polarity Classification	-->	Calling Count:1
# 2024-06-04 21:02:02,331 INFO: tokenizer:DebertaV2TokenizerFast(name_or_path='microsoft/deberta-v3-base', vocab_size=128000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '[CLS]', 'eos_token': '[SEP]', 'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True)	-->	Calling Count:0
# 2024-06-04 21:02:02,331 INFO: use_amp:False	-->	Calling Count:135
# 2024-06-04 21:02:02,331 INFO: use_bert_spc:True	-->	Calling Count:159
# 2024-06-04 21:02:02,331 INFO: use_syntax_based_SRD:False	-->	Calling Count:1430
# 2024-06-04 21:02:02,332 INFO: verbose:False	-->	Calling Count:1
# 2024-06-04 21:02:02,332 INFO: warmup_step:-1	-->	Calling Count:69
# 2024-06-04 21:02:02,333 INFO: window:lr	-->	Calling Count:0
